# %% [markdown]
# # Read Batch 1 from Parquet with Polars
# This notebook reads batch 1 data from the parquet file using Polars.

# %%
import polars as pl

# %% [markdown]
# ## Load Batch 1

# %%
# Read the first batch parquet file
file_path = "/mnt/samsung/wiki-data/wiki_data_batch_00001.parquet"
df = pl.read_parquet(file_path)

# Display basic info
print(f"Total records in batch 1: {len(df)}")
print(f"Columns: {df.columns}")
print(f"Shape: {df.shape}")
# Out:
# Total records in batch 1: 50000
# Columns: ['title', 'text']
# Shape: (50000, 2)

# %%
# Read the first batch from clean data
clean_file_path = "/mnt/samsung/wiki-data-clean/wiki_data_batch_00001.parquet"
df_clean = pl.read_parquet(clean_file_path)

# Display basic info
print(f"Total records in clean batch 1: {len(df_clean)}")
print(f"Columns: {df_clean.columns}")
print(f"Shape: {df_clean.shape}")
# Out:
# Total records in clean batch 1: 37308
# Columns: ['title', 'text']
# Shape: (37308, 2)

# %% [markdown]
# ## Load Batch 1 from Clean Data

# %% [markdown]
# ## Data Preview

# %%
# Display first 10 records
df.head(10)
# Out:
# shape: (10, 2)
# ┌────────────────────────────────┬─────────────────────────────────┐
# │ title                          ┆ text                            │
# │ ---                            ┆ ---                             │
# │ str                            ┆ str                             │
# ╞════════════════════════════════╪═════════════════════════════════╡
# │ AccessibleComputing            ┆ #REDIRECT [[Computer accessibi… │
# │ Anarchism                      ┆ {{short description|Political … │
# │ AfghanistanHistory             ┆ #REDIRECT [[History of Afghani… │
# │ AfghanistanGeography           ┆ #REDIRECT [[Geography of Afgha… │
# │ AfghanistanPeople              ┆ #REDIRECT [[Demographics of Af… │
# │ AfghanistanCommunications      ┆ #REDIRECT [[Communications in … │
# │ AfghanistanTransportations     ┆ #REDIRECT [[Transport in Afgha… │
# │ AfghanistanMilitary            ┆ #REDIRECT [[Afghan Armed Force… │
# ...

# %% [markdown]
# ## clean data

# %%
df_clean.head(10)
# Out:
# shape: (10, 2)
# ┌─────────────────────────────────┬─────────────────────────────────┐
# │ title                           ┆ text                            │
# │ ---                             ┆ ---                             │
# │ str                             ┆ str                             │
# ╞═════════════════════════════════╪═════════════════════════════════╡
# │ Anarchism                       ┆ {{short description|Political … │
# │ Albedo                          ┆ {{Short description|Ratio of h… │
# │ A                               ┆ {{Short description|First lett… │
# │ Alabama                         ┆ {{Short description|U.S. state… │
# │ Achilles                        ┆ {{short description|Greek myth… │
# │ Abraham Lincoln                 ┆ {{Short description|President … │
# │ Aristotle                       ┆ {{Short description|Ancient Gr… │
# │ An American in Paris            ┆ {{short description|Symphonic … │
# ...

# %%
# Filter out rows with #REDIRECT in the second column
df_subset = df.filter(~pl.col(df.columns[1]).str.contains("#REDIRECT"))
df_subset.head(10)
# Out:
# shape: (10, 2)
# ┌─────────────────────────────────┬─────────────────────────────────┐
# │ title                           ┆ text                            │
# │ ---                             ┆ ---                             │
# │ str                             ┆ str                             │
# ╞═════════════════════════════════╪═════════════════════════════════╡
# │ Anarchism                       ┆ {{short description|Political … │
# │ Albedo                          ┆ {{Short description|Ratio of h… │
# │ A                               ┆ {{Short description|First lett… │
# │ Alabama                         ┆ {{Short description|U.S. state… │
# │ Achilles                        ┆ {{short description|Greek myth… │
# │ Abraham Lincoln                 ┆ {{Short description|President … │
# │ Aristotle                       ┆ {{Short description|Ancient Gr… │
# │ An American in Paris            ┆ {{short description|Symphonic … │
# ...

# %%
df_subset.shape
# Out:
# (37308, 2)

# %% [markdown]
# ## Look at column

# %%
response = str(df_subset.select("text")[0, :])
print(response)
# Out:
# shape: (1, 1)
# ┌─────────────────────────────────┐
# │ text                            │
# │ ---                             │
# │ str                             │
# ╞═════════════════════════════════╡
# │ {{short description|Political … │
# └─────────────────────────────────┘

# %% [markdown]
# ## Read Second Column as Dictionary

# %%
import json

# Get the second column (text) from the first row
second_col_value = df_subset.select("text")[0, 0]
print(f"Second column value (first row):\n{second_col_value}")

# Try to parse as JSON if it contains JSON structure
try:
    parsed_dict = json.loads(second_col_value)
    print(f"\nParsed as dictionary:\n{json.dumps(parsed_dict, indent=2)}")
except json.JSONDecodeError:
    print(f"\nCould not parse as JSON. Raw text length: {len(second_col_value)} characters")
    # Alternative: create a dictionary with metadata about the text
    text_dict = {
        "content": second_col_value[:200],
        "length": len(second_col_value),
        "type": "wiki_markup"
    }
    print(f"\nAs dictionary with metadata:\n{json.dumps(text_dict, indent=2)}")
# Out:
# Second column value (first row):
# {{short description|Political philosophy and movement}}
# {{other uses}}
# {{redirect2|Anarchist|Anarchists|other uses|Anarchist (disambiguation)}}
# {{distinguish|Anarchy}}
# {{good article}}
# {{pp-semi-indef}}
# {{use British English|date=August 2021}}
# {{use dmy dates|date=August 2021}}
# {{anarchism sidebar}}
# {{basic forms of government}}
#
# ...

# %% [markdown]
# ## Data Schema

# %%
# Display schema
df.schema
# Out:
# Schema([('title', String), ('text', String)])

# %% [markdown]
# ## Summary Statistics

# %%
# Display summary statistics
df.describe()
# Out:
# shape: (9, 3)
# ┌────────────┬────────────────────┬─────────────────────────────────┐
# │ statistic  ┆ title              ┆ text                            │
# │ ---        ┆ ---                ┆ ---                             │
# │ str        ┆ str                ┆ str                             │
# ╞════════════╪════════════════════╪═════════════════════════════════╡
# │ count      ┆ 50000              ┆ 50000                           │
# │ null_count ┆ 0                  ┆ 0                               │
# │ mean       ┆ null               ┆ null                            │
# │ std        ┆ null               ┆ null                            │
# │ min        ┆ ! (disambiguation) ┆ 	{{Use mdy dates|date=August 2… │
# │ 25%        ┆ null               ┆ null                            │
# │ 50%        ┆ null               ┆ null                            │
# │ 75%        ┆ null               ┆ null                            │
# ...
